# %%
# lemmitation out put we get is lemma which is a root word rather than root stem

# %%
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Pass pos='v' to specify 'going' is a verb
lemmatizer.lemmatize('going', pos='v')  # Output: 'go'
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# 'go'

# %%
lemmatizer.lemmatize('going')
# Out:
# 'going'

# %%
lemmatizer.lemmatize('going' , 'ab')
# Out:
# 'going'

# %%
words = ["eating" , "eats" , "eaten" , "writing" , "writes" , "programming" , "programs","history" , "finally" , "finalized"]

# %%
for word in words:
  print(word + '---->' , lemmatizer.lemmatize(word , 'v'))
# Out:
# eating----> eat
# eats----> eat
# eaten----> eat
# writing----> write
# writes----> write
# programming----> program
# programs----> program
# history----> history
# finally----> finally
# finalized----> finalize

# %% [markdown]
# uses wordnet corpus takes more time -> Qna Chatbots text summarization

# %%
lemmatizer.lemmatize('fairly' , 'v')
# Out:
# 'fairly'

# %%
# !curl -s -o colab_push.py https://raw.githubusercontent.com/somyaknotfound/genai-langchain/main/scripts/colab_push.py
from colab_push import push
push("Lemmatization.ipynb")
