# %%
# !curl -s -o colab_push.py https://raw.githubusercontent.com/somyaknotfound/genai-langchain/main/scripts/colab_push.py
from colab_push import push
push("StemmingNltk.ipynb")
# Out:
# Pushed notebooks/StemmingNltk.ipynb to somyaknotfound/genai-langchain

# %%
words = ["eating" , "eats" , "eaten" , "writing" , "writes" , "programming" , "programs","history" , "finally" , "finalized"]

# %%
## PortStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
  print(word+'---->'+ stemming.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->histori
# finally---->final
# finalized---->final

# %%
# histori changes word meaning

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem('sitting')
# Out:
# 'sit'

# %%
# fixed with lemminization

# %%
# regexp stemmer class

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$' , min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('sexting')
# Out:
# 'sext'

# %%
reg_stemmer.stem('ingstemming')
# Out:
# 'ingstemm'

# %%
reg_stemmer.stem('disable')
# Out:
# 'dis'

# %%
##SnowBall Stemming better stemming

# %%
from nltk.stem import SnowballStemmer

# %%
snowballStemmer = SnowballStemmer('english')

# %%
for word in words:
  print(word+'----->'+ snowballStemmer.stem(word))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eaten
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->histori
# finally----->final
# finalized----->final

# %%
# the difference

# %%
stemming.stem('fairly') , stemming.stem('sportingly')
# Out:
# ('fairli', 'sportingli')

# %%
snowballStemmer.stem('fairly') , snowballStemmer.stem('sportingly')
# Out:
# ('fair', 'sport')

# %%
# cant use in chatbots lemminization is used as it consists of all the words

# %%
# !curl -s -o colab_push.py https://raw.githubusercontent.com/somyaknotfound/genai-langchain/main/scripts/colab_push.py
from colab_push import push
push("StemmingNltk.ipynb")
